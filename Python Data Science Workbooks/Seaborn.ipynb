# %%
import seaborn as sns
# %matplotlib inline
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
###Distplot
sns.distplot(tips["total_bill"], kde = True)
# Out:
# /var/folders/b6/l1n962ss59n521_0vxpckrcr0000gn/T/ipykernel_5020/3665013557.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde = True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"], kde = False, bins = 50)
# Out:
# /var/folders/b6/l1n962ss59n521_0vxpckrcr0000gn/T/ipykernel_5020/3620977537.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde = False, bins = 50)
# <Axes: xlabel='total_bill'>

# %%
###Jointplot for bivariate dataset
sns.jointplot(x="total_bill", y="tip", data = tips)

# %%
####Hexagonal Jointplot
sns.jointplot(x="total_bill", y="tip", data = tips, kind="hex")

# %%
##Regression Line and Jointplot
sns.jointplot(x="total_bill", y="tip", data = tips, kind = "reg")

# %%
##KDE and Jointplot
sns.set_style('darkgrid')
sns.jointplot(x="total_bill", y="tip", data = tips, kind = "kde",fill = True )

# %%
##Pairplot (for all variables)
sns.pairplot(data=tips)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Pairplot (for all variables) with hue
sns.pairplot(data=tips, hue="sex")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
###Rugplot (plots sticks to indicate density for only one variable)
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
##Rugplot and Distplot together
sns.distplot(tips['total_bill'], kde = False)
sns.rugplot(tips['total_bill'], color = 'red')
# Out:
# /var/folders/b6/l1n962ss59n521_0vxpckrcr0000gn/T/ipykernel_5020/1675086132.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde = False)
# <Axes: xlabel='total_bill'>

# %%
####Adding the KDE plot
sns.distplot(tips['total_bill'])
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'], color = 'red')
# Out:
# /var/folders/b6/l1n962ss59n521_0vxpckrcr0000gn/T/ipykernel_5020/271197613.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['tip'])
sns.kdeplot(tips['tip'])
sns.rugplot(tips['tip'], color = 'red')
# Out:
# /var/folders/b6/l1n962ss59n521_0vxpckrcr0000gn/T/ipykernel_5020/1936311700.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
####Understanding KDE Plots

# Step 1: Importing couple of libraries to use 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Creating dataset to use
dataset = np.random.randn(20)

# Creating rugplot using dataset
sns.rugplot(dataset);

# Setting up the x-axis for the plot using max and min values in the dataset
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# creating 100 equally spaced points from x_min to x_max using np.linspace()
x_axis = np.linspace(x_min,x_max,100)

# Setting up the bandwidth, follow the wikipedia link for more information:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Creating an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis) #shift+tab if you want to know more about the function! 
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# We need to sum the basis functions to get the kde plot.

# Plotting the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plotting figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Adding the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Getting rid of y-tick marks
plt.yticks([])

# Setting title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
##Swarm plots and strip plots Show each observation at each level of the categorical variable
##Boxplot and violin plot show the abstract representation of each distribution of the observation
##Barplot and point plot Apply a statistical estimation that show a measure of central tendency
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##Strip plot
#Plots a scatter plot where one variable is categorical;
sns.stripplot(x='day', y='total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##To enable overlap of the observations in each category, set jitter = False
sns.stripplot(x='day', y='total_bill', data = tips, jitter = False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data = tips, jitter = True,  hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##Swarmplot
sns.swarmplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x= 'total_bill', y= 'day', data = tips, hue = 'time')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#Boxplot
#Facilitates comparison between variables or cross-comparison between variables
sns.boxplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex', palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##Violin plot
##This combines the box plot and the KDE plot
sns.violinplot(x= 'day', y= 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
###Split and hue can be used to further categorise your plots
sns.violinplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex', split=True)
###Violin plots are complex, and should be used with data experts
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Statistical estimation within categories
#Bar plot is a general plot that allows us to aggregate the categorical data based on some estimator metric
##Default estimator is mean
sns.barplot(x='day', y='total_bill', hue = 'sex', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##To get the stdev of the data, we use numoy's stdev
sns.barplot(x='day', y='total_bill', hue = 'sex', data = tips, estimator = np.std)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
###Countplot is used to show the number of observations in each category
sns.countplot(x='day', hue = 'sex', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='size', data = tips)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
###Pointplot
##Pointplot plots the bar estimates and confidence interval
sns.pointplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex')
sns.barplot(x= 'day', y= 'total_bill', data = tips, hue = 'sex', alpha = .5)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##Combining plots
sns.violinplot(x= 'day', y= 'total_bill', data = tips)
sns.swarmplot(x= 'day', y= 'total_bill', data = tips, color = 'black', size = 3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##Cat Plot
###Cat plot can plot any of the above plots using the kind argument 
sns.catplot(x= 'day', y= 'total_bill', data = tips, hue = 'smoker', kind = 'box')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x= 'day', y= 'total_bill', col = 'time', data = tips, hue = 'smoker', kind = 'swarm')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x= 'day', y= 'total_bill', col = 'day', data = tips, hue = 'smoker', kind = 'box')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x= 'day', y= 'total_bill', col = 'day', data = tips, hue = 'smoker', kind = 'box', aspect = 0.5)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Axis Grid
##Draw multiple instances on the same plot using different facets of our data
#Pairplot, Jointplot and FacetPlot 
#To use axisgrid, your data must be structured such that each column is a variable and each row is an observation
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
iris = sns.load_dataset("iris")
tips = sns.load_dataset("tips")

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Facet Grid
#Used to visualize distribution of a variable, or the relationship between two variables
tips['day'].nunique(), tips['time'].nunique(), tips['smoker'].nunique()
# Out:
# (4, 2, 2)

# %%
#Initialise facetgrid
sns.FacetGrid(data = tips, col = 'time', row = 'smoker')

# %%
#To visualise data, use facetgrid.map
##Histogram on facet grid
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')
g.map(plt.hist, 'total_bill')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Scatterplot on facet grid
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')
g.map(plt.scatter, 'total_bill', 'tip')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
###Adding hue
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker', hue = 'sex')
g.map(plt.scatter, 'total_bill', 'tip').add_legend()
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Pairgrid
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
###initialise the grid
sns.PairGrid(data = iris)

# %%
g = sns.PairGrid(data = iris)
g.map(plt.scatter)

# %%
##Plotting histogram on only diagonal
g = sns.PairGrid(data = iris)
g.map_diag(plt.hist)

# %%
###Plotting histogram on diagonal and scatterplot on all other grids
g = sns.PairGrid(data = iris)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
###Plotting histogram on diagonal and scatterplot on all other grids
##Add hue for sex
g = sns.PairGrid(data = iris, hue = 'species')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %%
###Plotting histogram on diagonal and scatterplot on all other grids
##Add hue for sex
g = sns.PairGrid(data = iris, hue = 'species')
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(x=data_k, label=label_k, color=color, **plot_kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:1544: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
##Compare with pairplot
sns.pairplot(data=iris, hue = 'species')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Jointgrid
##This is similar to the jointplot
sns.jointplot(x='total_bill', y='tip', data = tips)

# %%
g = sns.JointGrid(x='total_bill', y='tip', data = tips)

# %%
g = sns.JointGrid(x='total_bill', y='tip', data = tips)
g.plot(sns.regplot, sns.distplot)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:1880: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(self.x, **orient_kw_x, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:1886: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
###Matrix plot
#Heatmap and Clustermap
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#heatmap
#This plots rectangular data as a clolor encoded matrix
#Dataset should be in a matrix form (pivot table or correlation)
tips[['total_bill', 'tip', 'size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips[['total_bill', 'tip', 'size']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(tips[['total_bill', 'tip', 'size']].corr(), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
##Convert flight data to pivot table
ptf = flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
ptf
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
##Call heatmap on the data
sns.heatmap(ptf)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
#Check color schemes
sns.heatmap(ptf, cmap = 'magma', linecolor = 'white', linewidth = 1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
##Clustermap
##Uses hierarchical clustering to create a cluster version of the heat map
sns.clustermap(ptf)

# %%
sns.clustermap(ptf, cmap = 'coolwarm')

# %%
##Standardize colour scale 
sns.clustermap(ptf, cmap = 'coolwarm', standard_scale = 1)

# %%
###Regression Plots
##lmplot allows you to plot linear regression
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Compare with regplot
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
##Hue
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Adding markers for the hues
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', markers = ['o', 'v'])
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
###Increase marker size

sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', markers = ['o', 'v'], scatter_kws={'s':100})
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Columns and rows
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'sex', row = 'time')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
###Hue and column
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', hue = 'sex')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Size and aspect ratio
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', hue = 'sex', aspect=0.5, height = 9)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
###Figure aesthetics
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style(style = 'white')
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style(style = 'ticks')
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
##Despine
sns.countplot(x='sex', data = tips)
sns.despine(
    top=True,
    right=True,
    left=True,
    bottom=True)

# %%
#Size of plots
plt.figure(figsize = (12,3))
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y='tip', data = tips, height = 5, aspect = 2)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Scaling
sns.set_context(context='paper', font_scale=3, rc=None)
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Scaling
sns.set_context(context='paper', font_scale=1, rc=None)
sns.countplot(x='sex', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>
